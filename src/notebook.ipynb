# %%
# Import the modules themselves
from Objects.Dataset import Dataset 
from Objects.UPITSequence import UPITSequence 
from Objects.Parameters import Parameters 


data = Dataset("OriginalData\datasetmarvin.csv", {0: 'id', 1: 'x', 2: 'y', 3: 'z', 4: 'tonn', 7: 'profit'})
param = Parameters(45, 60 * 10**6, 20 * 10**6, 3)

sequences = UPITSequence(data, param) 
sequences.run()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-07
# Set parameter MIPGap to value 0.1
# 0.3471090793609619
# 13.574647188186646
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 703919 rows, 106542 columns and 1407838 nonzeros
# Model fingerprint: 0x9b5e5d54
# Variable types: 0 continuous, 106542 integer (106542 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 638242 rows and 99386 columns (presolve time = 5s) ...
# Presolve removed 650986 rows and 100315 columns
# Presolve time: 6.94s
# Presolved: 52933 rows, 6227 columns, 105866 nonzeros
# Found heuristic solution: objective 6.634541e+08
# Variable types: 0 continuous, 6227 integer (6227 binary)
# Found heuristic solution: objective 6.693062e+08
# Root relaxation presolved: 6224 rows, 59145 columns, 112066 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.4987507e+08   1.252182e+09   0.000000e+00      7s
#    21841    1.3965396e+09   0.000000e+00   0.000000e+00     10s
#    21841    1.3965396e+09   0.000000e+00   0.000000e+00     10s
#    21841    1.3965396e+09   0.000000e+00   0.000000e+00     10s
#
# Root relaxation: objective 1.396540e+09, 21841 iterations, 2.75 seconds (2.50 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.396540e+09 1.3965e+09  0.00%     -    9s
#
# Explored 1 nodes (21841 simplex iterations) in 10.08 seconds (8.96 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1.39654e+09 6.69306e+08 6.63454e+08 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.396539647883e+09, best bound 1.396539647883e+09, gap 0.0000%
# 12.823262691497803
# Set parameter MIPGap to value 0.1
# 0.5814440250396729
# 1.8859546184539795
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 90260 rows, 16454 columns and 196970 nonzeros
# Model fingerprint: 0xfd9feb41
# Variable types: 0 continuous, 16454 integer (16454 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 29167 rows and 6817 columns
# Presolve time: 2.74s
# Presolved: 61093 rows, 9637 columns, 131968 nonzeros
# Variable types: 0 continuous, 9637 integer (9637 binary)
# Found heuristic solution: objective 3.625524e+07
# Root relaxation presolved: 9624 rows, 70664 columns, 141454 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    14990    1.6749132e+08   4.460493e+06   0.000000e+00      5s
#    20755    1.8488403e+08   0.000000e+00   0.000000e+00      6s
#    20755    1.8488403e+08   0.000000e+00   0.000000e+00      6s
#    20755    1.8488403e+08   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 1.848840e+08, 20755 iterations, 3.39 seconds (3.58 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8488e+08    0   64 3.6255e+07 1.8488e+08   410%     -    6s
# H    0     0                    1.833738e+08 1.8488e+08  0.82%     -    6s
#
# Explored 1 nodes (20755 simplex iterations) in 6.66 seconds (5.81 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.83374e+08 3.62552e+07 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.833737770659e+08, best bound 1.848840304191e+08, gap 0.8236%
# 7.112712621688843
# Set parameter MIPGap to value 0.1
# 0.5994353294372559
# 1.44815993309021
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 74716 rows, 14702 columns and 164130 nonzeros
# Model fingerprint: 0xb7499bf6
# Variable types: 0 continuous, 14702 integer (14702 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 17995 rows and 5354 columns
# Presolve time: 1.66s
# Presolved: 56721 rows, 9348 columns, 122918 nonzeros
# Variable types: 0 continuous, 9348 integer (9348 binary)
# Found heuristic solution: objective 2.757380e+07
# Root relaxation presolved: 9338 rows, 66013 columns, 132150 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    20762    1.7217160e+08   1.432631e+04   0.000000e+00      5s
#    20871    1.7220746e+08   0.000000e+00   0.000000e+00      5s
#    20871    1.7220746e+08   0.000000e+00   0.000000e+00      5s
#    20871    1.7220746e+08   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 1.722075e+08, 20871 iterations, 3.40 seconds (3.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7221e+08    0  144 2.7574e+07 1.7221e+08   525%     -    5s
# H    0     0                    1.694008e+08 1.7221e+08  1.66%     -    6s
#
# Explored 1 nodes (20871 simplex iterations) in 6.02 seconds (4.99 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.69401e+08 2.75738e+07 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.694007761821e+08, best bound 1.722074575454e+08, gap 1.6568%
# 6.382565975189209
# Set parameter MIPGap to value 0.1
# 0.49567389488220215
# 1.5997192859649658
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 63302 rows, 13350 columns and 139950 nonzeros
# Model fingerprint: 0xfa9145db
# Variable types: 0 continuous, 13350 integer (13350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 9140 rows and 4279 columns
# Presolve time: 2.33s
# Presolved: 54162 rows, 9071 columns, 117507 nonzeros
# Variable types: 0 continuous, 9071 integer (9071 binary)
# Found heuristic solution: objective 5885159.6289
# Root relaxation presolved: 9066 rows, 63223 columns, 126558 nonzeros
#
#
# Root relaxation: objective 1.583024e+08, 21060 iterations, 1.28 seconds (1.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.5830e+08    0   29 5885159.63 1.5830e+08  2590%     -    3s
# H    0     0                    1.560360e+08 1.5830e+08  1.45%     -    4s
#
# Explored 1 nodes (21060 simplex iterations) in 4.06 seconds (2.51 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.56036e+08 5.88516e+06 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.560360054027e+08, best bound 1.583023963123e+08, gap 1.4525%
# 4.456252574920654
# Set parameter MIPGap to value 0.1
# 0.4343843460083008
# 1.4067413806915283
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 52234 rows, 11820 columns and 116284 nonzeros
# Model fingerprint: 0x08009307
# Variable types: 0 continuous, 11820 integer (11820 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 5710 rows and 3647 columns
# Presolve time: 0.81s
# Presolved: 46524 rows, 8173 columns, 101335 nonzeros
# Variable types: 0 continuous, 8173 integer (8173 binary)
# Found heuristic solution: objective 5887967.7158
# Root relaxation presolved: 8171 rows, 54693 columns, 109501 nonzeros
#
#
# Root relaxation: objective 1.373998e+08, 16903 iterations, 0.86 seconds (0.88 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3740e+08    0  250 5887967.72 1.3740e+08  2234%     -    2s
# H    0     0                    1.229186e+08 1.3740e+08  11.8%     -    2s
# H    0     0                    1.371108e+08 1.3740e+08  0.21%     -    2s
#
# Explored 1 nodes (16903 simplex iterations) in 2.35 seconds (1.92 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1.37111e+08 1.22919e+08 5.88797e+06 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.371108011042e+08, best bound 1.373997970550e+08, gap 0.2108%
# 2.706160068511963
# Set parameter MIPGap to value 0.1
# 0.3640298843383789
# 0.9135823249816895
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 43264 rows, 10454 columns and 96978 nonzeros
# Model fingerprint: 0x102524b7
# Variable types: 0 continuous, 10454 integer (10454 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4468 rows and 3282 columns
# Presolve time: 0.31s
# Presolved: 38796 rows, 7172 columns, 84879 nonzeros
# Variable types: 0 continuous, 7172 integer (7172 binary)
# Found heuristic solution: objective 2340197.8892
# Root relaxation presolved: 7172 rows, 45968 columns, 92051 nonzeros
#
#
# Root relaxation: objective 1.157964e+08, 9844 iterations, 0.28 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1580e+08    0   40 2340197.89 1.1580e+08  4848%     -    0s
# H    0     0                    1.143538e+08 1.1580e+08  1.26%     -    0s
#
# Explored 1 nodes (9844 simplex iterations) in 0.79 seconds (0.76 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.14354e+08 2.3402e+06 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.143538273731e+08, best bound 1.157964091575e+08, gap 1.2615%
# 1.0661404132843018
# Set parameter MIPGap to value 0.1
# 0.46324801445007324
# 0.7081077098846436
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 33845 rows, 8868 columns and 76554 nonzeros
# Model fingerprint: 0x51ca0185
# Variable types: 0 continuous, 8868 integer (8868 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3753 rows and 2897 columns
# Presolve time: 0.21s
# Presolved: 30092 rows, 5971 columns, 66270 nonzeros
# Variable types: 0 continuous, 5971 integer (5971 binary)
# Found heuristic solution: objective 3246506.6733
# Root relaxation presolved: 5971 rows, 36063 columns, 72241 nonzeros
#
#
# Root relaxation: objective 9.569812e+07, 9073 iterations, 0.28 seconds (0.30 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9.5698e+07    0   31 3246506.67 9.5698e+07  2848%     -    0s
# H    0     0                    9.459160e+07 9.5698e+07  1.17%     -    0s
#
# Explored 1 nodes (9073 simplex iterations) in 0.63 seconds (0.64 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 9.45916e+07 3.24651e+06 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.459159973361e+07, best bound 9.569812498918e+07, gap 1.1698%
# 0.8696868419647217
# Set parameter MIPGap to value 0.1
# 0.2503013610839844
# 0.5475723743438721
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 25287 rows, 7302 columns and 57872 nonzeros
# Model fingerprint: 0x7c34c632
# Variable types: 0 continuous, 7302 integer (7302 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3135 rows and 2518 columns
# Presolve time: 0.14s
# Presolved: 22152 rows, 4784 columns, 49200 nonzeros
# Variable types: 0 continuous, 4784 integer (4784 binary)
# Found heuristic solution: objective 3299073.6792
#
# Root relaxation: objective 7.414231e+07, 4695 iterations, 0.34 seconds (0.62 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.4142e+07    0  377 3299073.68 7.4142e+07  2147%     -    0s
# H    0     0                    6.888987e+07 7.4142e+07  7.62%     -    0s
#
# Explored 1 nodes (4695 simplex iterations) in 0.76 seconds (0.95 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 6.88899e+07 3.29907e+06 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.888987458023e+07, best bound 7.414231381285e+07, gap 7.6244%
# 0.9394192695617676
# Set parameter MIPGap to value 0.1
# 0.20542192459106445
# 0.39098572731018066
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 17148 rows, 5624 columns and 39916 nonzeros
# Model fingerprint: 0xe1c3fc56
# Variable types: 0 continuous, 5624 integer (5624 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+02, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 2477 rows and 2057 columns
# Presolve time: 0.11s
# Presolved: 14671 rows, 3567 columns, 33002 nonzeros
# Variable types: 0 continuous, 3567 integer (3567 binary)
# Found heuristic solution: objective 2146817.1323
#
# Root relaxation: objective 5.458209e+07, 4138 iterations, 0.24 seconds (0.38 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.4582e+07    0   94 2146817.13 5.4582e+07  2442%     -    0s
# H    0     0                    5.378118e+07 5.4582e+07  1.49%     -    0s
#
# Explored 1 nodes (4138 simplex iterations) in 0.44 seconds (0.53 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 5.37812e+07 2.14682e+06 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.378117893693e+07, best bound 5.458209471521e+07, gap 1.4892%
# 0.5873961448669434
# Set parameter MIPGap to value 0.1
# 0.13759899139404297
# 0.25036072731018066
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 10093 rows, 4024 columns and 24206 nonzeros
# Model fingerprint: 0x82316e66
# Variable types: 0 continuous, 4024 integer (4024 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+02, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 1830 rows and 1579 columns
# Presolve time: 0.06s
# Presolved: 8263 rows, 2445 columns, 19045 nonzeros
# Variable types: 0 continuous, 2445 integer (2445 binary)
# Found heuristic solution: objective 329998.56494
#
# Root relaxation: objective 3.448826e+07, 3928 iterations, 0.16 seconds (0.22 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.4488e+07    0  115 329998.565 3.4488e+07      -     -    0s
# H    0     0                    3.336830e+07 3.4488e+07  3.36%     -    0s
#
# Explored 1 nodes (3928 simplex iterations) in 0.28 seconds (0.32 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3.33683e+07 329999 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.336830189041e+07, best bound 3.448826043060e+07, gap 3.3564%
# 0.3804585933685303
# Set parameter MIPGap to value 0.1
# 0.07875943183898926
# 0.1296827793121338
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4323 rows, 2290 columns and 10932 nonzeros
# Model fingerprint: 0x100cc0a9
# Variable types: 0 continuous, 2290 integer (2290 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [4e+03, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 1085 rows and 994 columns
# Presolve time: 0.03s
# Presolved: 3238 rows, 1296 columns, 7818 nonzeros
# Variable types: 0 continuous, 1296 integer (1296 binary)
# Found heuristic solution: objective 143206.25764
#
# Root relaxation: objective 1.386872e+07, 1473 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3869e+07    0  139 143206.258 1.3869e+07  9584%     -    0s
# H    0     0                    1.370463e+07 1.3869e+07  1.20%     -    0s
#
# Explored 1 nodes (1473 simplex iterations) in 0.07 seconds (0.05 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.37046e+07 143206 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.370462611139e+07, best bound 1.386872297782e+07, gap 1.1974%
# 0.13394975662231445
# Set parameter MIPGap to value 0.1
# 0.016958236694335938
# 0.02389979362487793
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 631 rows, 492 columns and 1750 nonzeros
# Model fingerprint: 0xe48ac327
# Variable types: 0 continuous, 492 integer (492 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [4e+03, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 467277.39174
# Presolve removed 613 rows and 481 columns
# Presolve time: 0.02s
# Presolved: 18 rows, 11 columns, 36 nonzeros
# Variable types: 0 continuous, 11 integer (11 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      467277.392 467277.392  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 467277 -0
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.672773917425e+05, best bound 4.672773917425e+05, gap 0.0000%
# 0.04512929916381836
# The code took 67.41957569122314 seconds to run!
# [{'iteration': 0,
#   'blocksMined':         id   x   y  z       tonn    profit
#   0    12077  13  31  0  61200.012 -4.000000
#   1    12092  13  32  0  61200.012 -4.000000
#   2    12107  13  33  0  61200.012 -4.000000
#   3    12923  14  28  0  61200.012 -4.000000
#   4    12938  14  29  0  61200.012 -4.000000
#   ..     ...  ..  .. ..        ...       ...
#   871  27072  30  35  1  72360.001  6.139615
#   872  27086  30  36  0  61200.012 -4.000000
#   873  27101  30  37  0  61200.012 -4.000000
#   874  27914  31  34  0  62480.000 -2.015642
#   875  27929  31  35  0  61200.012 -4.000000
#
#   [876 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn     profit
#   0    15645  17  31  4  72360.001  11.159333
#   1    15660  17  32  4  72360.001  10.631419
#   2    16536  18  31  4  72360.001  14.373532
#   3    16551  18  32  4  72360.001  13.490764
#   4    16552  18  32  5  72360.001  14.219167
#   ..     ...  ..  .. ..        ...        ...
#   272  25343  28  34  1  66240.000   5.779290
#   273  25344  28  34  2  72360.001  10.771360
#   274  25345  28  34  3  72240.000  11.087596
#   275  25360  28  35  3  72360.001  12.454397
#   276  26202  29  34  2  72240.005   9.157364
#
#   [277 rows x 6 columns],
#   'objectiveValue': 183373777.06585714},
#  {'iteration': 1,
#   'blocksMined':         id   x   y  z       tonn    profit
#   0    11185  12  31  0  61200.012 -4.000000
#   1    11200  12  32  0  61200.012 -4.000000
#   2    11215  12  33  0  61200.012 -4.000000
#   3    12032  13  28  0  61200.012 -4.000000
#   4    12047  13  29  0  61200.012 -4.000000
#   ..     ...  ..  .. ..        ...       ...
#   671  28714  32  30  0  65580.000 -1.037514
#   672  28742  32  32  0  71550.018  2.170807
#   673  28756  32  33  0  71550.018  1.319880
#   674  28771  32  34  0  69350.014  0.408673
#   675  28786  32  35  0  62200.000 -3.145794
#
#   [676 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn     profit
#   0    15646  17  31  5  72360.001  10.147600
#   1    15661  17  32  5  72360.001  10.331994
#   2    16522  18  30  5  72360.001  11.386975
#   3    16538  18  31  6  72360.001  14.595229
#   4    16553  18  32  6  72360.001  14.680335
#   ..     ...  ..  .. ..        ...        ...
#   271  25375  28  36  3  72360.001  10.514157
#   272  26173  29  32  3  71550.000   7.948492
#   273  26203  29  34  3  71670.000   7.676797
#   274  26218  29  35  3  72240.005  10.327527
#   275  27930  31  35  1  72240.005   7.484810
#
#   [276 rows x 6 columns],
#   'objectiveValue': 169400776.18205258},
#  {'iteration': 2,
#   'blocksMined':         id   x   y  z       tonn    profit
#   0    10292  11  31  0  61200.012 -4.000000
#   1    10307  11  32  0  61200.012 -4.000000
#   2    10322  11  33  0  61200.012 -4.000000
#   3    10337  11  34  0  61200.012 -4.000000
#   4    11140  12  28  0  61200.012 -4.000000
#   ..     ...  ..  .. ..        ...       ...
#   760  30515  34  37  0  62200.000 -3.034732
#   761  30530  34  38  0  61200.012 -4.000000
#   762  31318  35  34  0  62100.000 -3.695946
#   763  31332  35  35  0  68000.000 -1.336645
#   764  31346  35  36  0  71550.018  0.788514
#
#   [765 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn     profit
#   0    15631  17  30  5  72360.001   8.118065
#   1    15647  17  31  6  72360.001  10.668243
#   2    15662  17  32  6  72360.001  10.673010
#   3    15692  17  34  6  72360.001   7.395988
#   4    16413  18  23  1  68260.000   2.078837
#   ..     ...  ..  .. ..        ...        ...
#   272  27120  30  38  4  72360.001  11.573404
#   273  27945  31  36  1  66240.000   2.008129
#   274  27948  31  36  4  71550.000   4.713094
#   275  28802  32  36  1  66180.000   3.109118
#   276  29654  33  36  1  67770.000   1.887301
#
#   [277 rows x 6 columns],
#   'objectiveValue': 156036005.40267628},
#  {'iteration': 3,
#   'blocksMined':         id   x   y  z       tonn    profit
#   0     9398  10  31  0  61200.012 -4.000000
#   1     9413  10  32  0  61200.012 -4.000000
#   2     9428  10  33  0  61200.012 -4.000000
#   3     9443  10  34  0  61200.012 -4.000000
#   4     9458  10  35  0  61200.012 -4.000000
#   ..     ...  ..  .. ..        ...       ...
#   678  31375  35  38  0  62700.000 -2.786714
#   679  32148  36  33  0  61200.012 -4.000000
#   680  32162  36  34  0  61200.012 -4.000000
#   681  32176  36  35  0  61200.012 -4.000000
#   682  32190  36  36  0  66600.000 -2.048980
#
#   [683 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn     profit
#   0    15601  17  28  5  72360.001   6.147529
#   1    15617  17  29  6  72360.001   7.631511
#   2    15632  17  30  6  72360.001   8.722504
#   3    15648  17  31  7  72360.001  11.476382
#   4    15663  17  32  7  72360.001  11.413090
#   ..     ...  ..  .. ..        ...        ...
#   271  27106  30  37  5  71670.000   7.153987
#   272  27121  30  38  5  72330.002  10.724138
#   273  27135  30  39  4  72360.001   8.815120
#   274  27963  31  37  4  71730.000   6.101227
#   275  27978  31  38  4  72330.002   9.929884
#
#   [276 rows x 6 columns],
#   'objectiveValue': 137110801.10419688},
#  {'iteration': 4,
#   'blocksMined':         id   x   y  z       tonn    profit
#   0     8506   9  31  0  61200.012 -4.000000
#   1     8521   9  32  0  61200.012 -4.000000
#   2     8536   9  33  0  61200.012 -4.000000
#   3     8551   9  34  0  61200.012 -4.000000
#   4     9353  10  28  0  61200.012 -4.000000
#   ..     ...  ..  .. ..        ...       ...
#   788  33018  37  35  0  61200.012 -4.000000
#   789  33019  37  35  1  61200.012 -4.000000
#   790  33032  37  36  0  61200.012 -4.000000
#   791  33046  37  37  0  61450.000 -3.893552
#   792  33859  38  35  0  61200.012 -4.000000
#
#   [793 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn    profit
#   0    14757  16  31  7  72360.001  6.947455
#   1    14831  16  36  6  72360.001  6.018207
#   2    14846  16  37  6  72360.001  6.758527
#   3    15602  17  28  6  72360.001  6.028101
#   4    15618  17  29  7  72360.001  8.002806
#   ..     ...  ..  .. ..        ...       ...
#   272  27965  31  37  6  71550.000  5.089316
#   273  27979  31  38  5  71850.000  6.487140
#   274  27993  31  39  4  72360.001  8.162056
#   275  27994  31  39  5  72330.002  8.445519
#   276  28850  32  39  4  72330.002  6.783199
#
#   [277 rows x 6 columns],
#   'objectiveValue': 114353827.37312326},
#  {'iteration': 5,
#   'blocksMined':         id   x   y  z       tonn  profit
#   0     7661   8  34  0  61200.012    -4.0
#   1     8552   9  34  1  61200.012    -4.0
#   2     8566   9  35  0  61200.012    -4.0
#   3     8581   9  36  0  61200.012    -4.0
#   4     8596   9  37  0  61200.012    -4.0
#   ..     ...  ..  .. ..        ...     ...
#   778  33060  37  38  0  61200.012    -4.0
#   779  33817  38  32  0  61200.012    -4.0
#   780  33831  38  33  0  61200.012    -4.0
#   781  33845  38  34  0  61200.012    -4.0
#   782  33873  38  36  0  61200.012    -4.0
#
#   [783 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn    profit
#   0    13955  15  37  6  72360.001  4.913034
#   1    14588  16  20  3  71120.003  3.522675
#   2    14803  16  34  8  72360.000  6.258741
#   3    14817  16  35  7  72360.001  6.156835
#   4    14832  16  36  7  72360.001  7.199075
#   ..     ...  ..  .. ..        ...       ...
#   273  27875  31  31  6  72360.001  5.008601
#   274  27891  31  32  7  72360.001  9.261203
#   275  27906  31  33  7  72360.000  6.456681
#   276  27980  31  38  6  71550.000  5.496134
#   277  28009  31  40  5  69200.000  3.404241
#
#   [278 rows x 6 columns],
#   'objectiveValue': 94591599.73360972},
#  {'iteration': 6,
#   'blocksMined':         id   x   y  z       tonn  profit
#   0     6769   7  34  0  61200.012    -4.0
#   1     7616   8  31  0  61200.012    -4.0
#   2     7631   8  32  0  61200.012    -4.0
#   3     7646   8  33  0  61200.012    -4.0
#   4     7662   8  34  1  61200.012    -4.0
#   ..     ...  ..  .. ..        ...     ...
#   834  34650  39  32  0  61200.012    -4.0
#   835  34664  39  33  0  61200.012    -4.0
#   836  34678  39  34  0  61200.012    -4.0
#   837  34692  39  35  0  61200.012    -4.0
#   838  34706  39  36  0  61200.012    -4.0
#
#   [839 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn    profit
#   0    13697  15  20  3  72030.006  3.326318
#   1    13712  15  21  3  71550.018  2.229942
#   2    13728  15  22  4  71550.018  2.601948
#   3    13956  15  37  7  72360.001  5.767422
#   4    14604  16  21  4  72210.007  4.104120
#   ..     ...  ..  .. ..        ...       ...
#   275  28851  32  39  5  71850.000  5.206393
#   276  29502  33  25  3  72360.001  3.437644
#   277  29503  33  25  4  72360.001  4.503250
#   278  29517  33  26  4  72360.001  3.423224
#   279  30350  34  25  3  72360.001  3.445511
#
#   [280 rows x 6 columns],
#   'objectiveValue': 68889874.5802296},
#  {'iteration': 7,
#   'blocksMined':         id   x   y  z       tonn  profit
#   0     6724   7  31  0  61200.012    -4.0
#   1     6739   7  32  0  61200.012    -4.0
#   2     6784   7  35  0  61200.012    -4.0
#   3     7571   8  28  0  61200.012    -4.0
#   4     7586   8  29  0  61200.012    -4.0
#   ..     ...  ..  .. ..        ...     ...
#   795  34622  39  30  0  61200.012    -4.0
#   796  34707  39  36  1  61200.012    -4.0
#   797  34720  39  37  0  61200.012    -4.0
#   798  34734  39  38  0  61200.012    -4.0
#   799  35536  40  36  0  61200.012    -4.0
#
#   [800 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn    profit
#   0    12806  14  20  3  70490.013  1.591359
#   1    13682  15  19  3  68240.000  1.617452
#   2    13698  15  20  4  72330.002  4.413872
#   3    13713  15  21  4  71760.017  2.930095
#   4    13729  15  22  5  71550.018  2.463800
#   ..     ...  ..  .. ..        ...       ...
#   276  31195  35  25  3  72360.001  2.680637
#   277  31196  35  25  4  72360.001  3.836115
#   278  31210  35  26  4  71120.003  2.229924
#   279  32023  36  24  1  74250.000  2.784080
#   280  32024  36  24  2  74250.000  2.989573
#
#   [281 rows x 6 columns],
#   'objectiveValue': 53781178.93692626},
#  {'iteration': 8,
#   'blocksMined':         id   x   y  z       tonn  profit
#   0     5832   6  31  0  61200.012    -4.0
#   1     5847   6  32  0  61200.012    -4.0
#   2     5877   6  34  0  61200.012    -4.0
#   3     5892   6  35  0  61200.012    -4.0
#   4     6679   7  28  0  61200.012    -4.0
#   ..     ...  ..  .. ..        ...     ...
#   862  35466  40  31  0  61200.012    -4.0
#   863  35480  40  32  0  61200.012    -4.0
#   864  35494  40  33  0  61200.012    -4.0
#   865  35508  40  34  0  61200.012    -4.0
#   866  35522  40  35  0  61200.012    -4.0
#
#   [867 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn    profit
#   0    12807  14  20  4  72030.006  2.599116
#   1    12822  14  21  4  70900.017  1.847285
#   2    12823  14  21  5  71640.015  2.168279
#   3    12838  14  22  5  71610.016  2.026626
#   4    12853  14  23  5  69860.008  0.855941
#   ..     ...  ..  .. ..        ...       ...
#   278  32025  36  24  3  74250.000  2.874074
#   279  32040  36  25  4  72360.001  2.043899
#   280  32852  37  23  2  71650.002  1.763069
#   281  32866  37  24  2  70950.000  1.667497
#   282  32881  37  25  3  72430.000  1.222292
#
#   [283 rows x 6 columns],
#   'objectiveValue': 33368301.890413713},
#  {'iteration': 9,
#   'blocksMined':         id   x   y  z       tonn  profit
#   0     4941   5  31  0  61200.012    -4.0
#   1     4956   5  32  0  61200.012    -4.0
#   2     4986   5  34  0  61200.012    -4.0
#   3     5787   6  28  0  61200.012    -4.0
#   4     5802   6  29  0  61200.012    -4.0
#   ..     ...  ..  .. ..        ...     ...
#   894  36327  41  33  0  61200.012    -4.0
#   895  36383  41  37  0  61200.012    -4.0
#   896  37055  42  25  0  61200.012    -4.0
#   897  37069  42  26  0  61200.012    -4.0
#   898  37083  42  27  0  61200.012    -4.0
#
#   [899 rows x 6 columns],
#   'blocksToPlant':         id   x   y  z       tonn    profit
#   0    11932  13  21  5  70650.017  0.742326
#   1    12793  14  19  5  67120.000  0.953170
#   2    12808  14  20  5  72330.002  3.593536
#   3    12824  14  21  6  71820.015  2.638556
#   4    12839  14  22  6  71550.018  1.776283
#   ..     ...  ..  .. ..        ...       ...
#   280  32868  37  24  4  73620.003  2.531045
#   281  32882  37  25  4  72570.007  2.130810
#   282  32883  37  25  5  71520.004  1.980180
#   283  33722  38  25  3  69480.000  0.111993
#   284  33723  38  25  4  72080.002  1.703736
#
#   [285 rows x 6 columns],
#   'objectiveValue': 13704626.111394387},
#  {'iteration': 10,
#   'blocksMined':         id   x   y  z       tonn  profit
#   0     6604   7  23  0  61200.012    -4.0
#   1     7451   8  20  0  61200.012    -4.0
#   2     7497   8  23  1  61200.012    -4.0
#   3     8296   9  17  0  61200.012    -4.0
#   4     8342   9  20  1  61200.012    -4.0
#   ..     ...  ..  .. ..        ...     ...
#   241  35565  40  38  1  61200.012    -4.0
#   242  36314  41  32  1  61200.012    -4.0
#   243  36341  41  34  0  61200.012    -4.0
#   244  36397  41  38  0  61200.012    -4.0
#   245  37153  42  32  0  61200.012    -4.0
#
#   [246 rows x 6 columns],
#   'blocksToPlant':        id   x   y   z       tonn    profit
#   0   11917  13  20   5  67380.000  0.059451
#   1   12809  14  20   6  72360.001  4.017043
#   2   12855  14  23   7  71550.018  1.524662
#   3   13747  15  23   8  71550.018  1.699877
#   4   14639  16  23   9  71850.000  3.191604
#   ..    ...  ..  ..  ..        ...       ...
#   62  28682  32  27  10  72360.000  0.784098
#   63  28709  32  29   9  72360.001  0.532124
#   64  28752  32  32  10  72360.001  2.413461
#   65  29690  33  38   8  71550.000  0.278731
#   66  30537  34  38   7  71580.000  1.388511
#
#   [67 rows x 6 columns],
#   'objectiveValue': 467277.3917425057}]

# %%
for upit in sequences.sequences.values():
    print(upit.model.objVal)
# Out:
# 183373777.06585714
# 171645073.9046232
# 156921455.33973044
# 135373905.1152015
# 115552284.49010894
# 94983318.82077077
# 74072941.47361904
# 52678949.5314206
# 33100808.75758748
# 11205051.456862489
# 258993.60430781374

# %%
for upit in sequences.sequences.values():
    print(upit.model.objVal)
# Out:
# 183373777.06585714
# 171645073.9046232
# 156921455.33973044
# 135373905.1152015
# 115552284.49010894
# 94983318.82077077
# 74072941.47361904
# 52678949.5314206
# 33100808.75758748
# 11205051.456862489

# %%
for upit in sequences.summary:
    print(upit['objectiveValue'])
# Out:
# 183373777.06585714
# 169400776.18205258
# 156036005.40267628
# 137110801.10419688
# 114353827.37312326
# 94591599.73360972
# 68889874.5802296
# 53781178.93692626
# 33368301.890413713
# 13704626.111394387
# 467277.3917425057

# %%
for model in sequences.sequences.values():
    print(model)
# Out:
# <Objects.UPIT.UPIT object at 0x0000022A8E117100>
# <Objects.UPIT.UPIT object at 0x0000022A9E167CD0>
# <Objects.UPIT.UPIT object at 0x0000022AA4FF4580>

# %%
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-07
# Set parameter MIPGap to value 0.001
# 0.31316208839416504
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 13.164812564849854
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 703919 rows, 106542 columns and 1407838 nonzeros
# Model fingerprint: 0x9b5e5d54
# Variable types: 0 continuous, 106542 integer (106542 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 641238 rows and 99588 columns (presolve time = 5s) ...
# Presolve removed 650986 rows and 100315 columns
# Presolve time: 6.40s
# Presolved: 52933 rows, 6227 columns, 105866 nonzeros
# Found heuristic solution: objective 6.634541e+08
# Variable types: 0 continuous, 6227 integer (6227 binary)
# Found heuristic solution: objective 6.693062e+08
# Root relaxation presolved: 6224 rows, 59145 columns, 112066 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.4987507e+08   1.252182e+09   0.000000e+00      7s
#    21841    1.3965396e+09   0.000000e+00   0.000000e+00      9s
#    21841    1.3965396e+09   0.000000e+00   0.000000e+00      9s
#    21841    1.3965396e+09   0.000000e+00   0.000000e+00      9s
#
# Root relaxation: objective 1.396540e+09, 21841 iterations, 2.61 seconds (2.50 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.396540e+09 1.3965e+09  0.00%     -    9s
#
# Explored 1 nodes (21841 simplex iterations) in 9.34 seconds (8.96 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1.39654e+09 6.69306e+08 6.63454e+08 -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.396539647883e+09, best bound 1.396539647883e+09, gap 0.0000%
# 12.071735143661499

# %%
param2 = Parameters(45, 60 * 10**6, 20 * 10**6, 3)

upitStep1 = UPIT(Dataset(upit.getBlocksMined()), param2)
print(upitStep1.dataset)
upitStep1.run()
count = 1
profit = []
profit.append(upitStep1.model.objVal)
blocksAvailable = upitStep1.getNotMined()
while True:
    nextUpit = UPIT(Dataset(blocksAvailable), param2)
    nextUpit.run()
    blocksAvailable = nextUpit.getNotMined()
    profit.append(nextUpit.model.objVal)
    count += 1
    if profit[-1] / sum(profit) < 0.01:
        break
print(count, sum(profit))
# Out:
# Set parameter MIPGap to value 0.001
# 0.5774569511413574
# <Objects.Dataset.Dataset object at 0x0000025190ED5430>
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 1.8005354404449463
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 90260 rows, 16454 columns and 196970 nonzeros
# Model fingerprint: 0xfd9feb41
# Variable types: 0 continuous, 16454 integer (16454 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 29167 rows and 6817 columns
# Presolve time: 2.79s
# Presolved: 61093 rows, 9637 columns, 131968 nonzeros
# Variable types: 0 continuous, 9637 integer (9637 binary)
# Found heuristic solution: objective 3.625524e+07
# Root relaxation presolved: 9624 rows, 70664 columns, 141454 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    13800    1.6749131e+08   5.622504e+06   0.000000e+00      5s
#    20755    1.8488403e+08   0.000000e+00   0.000000e+00      7s
#    20755    1.8488403e+08   0.000000e+00   0.000000e+00      7s
#    20755    1.8488403e+08   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 1.848840e+08, 20755 iterations, 3.95 seconds (3.58 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8488e+08    0   64 3.6255e+07 1.8488e+08   410%     -    7s
# H    0     0                    1.833738e+08 1.8488e+08  0.82%     -    7s
# H    0     0                    1.844512e+08 1.8488e+08  0.23%     -    7s
# H    0     0                    1.844576e+08 1.8488e+08  0.23%     -    7s
#      0     0 1.8488e+08    0   59 1.8446e+08 1.8488e+08  0.23%     -    8s
#      0     0 1.8488e+08    0   60 1.8446e+08 1.8488e+08  0.23%     -    9s
#      0     0 1.8488e+08    0    1 1.8446e+08 1.8488e+08  0.23%     -   10s
#      0     0 1.8465e+08    0   76 1.8446e+08 1.8465e+08  0.11%     -   11s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 1
#
# Explored 1 nodes (34716 simplex iterations) in 11.33 seconds (8.99 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1.84458e+08 1.84451e+08 1.83374e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.844576497028e+08, best bound 1.846180176304e+08, gap 0.0869%
# 11.794721603393555
# Set parameter MIPGap to value 0.001
# 0.5226411819458008
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 1.4550738334655762
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 74614 rows, 14690 columns and 163914 nonzeros
# Model fingerprint: 0xa0bc2df8
# Variable types: 0 continuous, 14690 integer (14690 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 17592 rows and 5368 columns
# Presolve time: 1.79s
# Presolved: 57022 rows, 9322 columns, 123479 nonzeros
# Variable types: 0 continuous, 9322 integer (9322 binary)
# Found heuristic solution: objective 2.571367e+07
# Root relaxation presolved: 9307 rows, 66312 columns, 132737 nonzeros
#
#
# Root relaxation: objective 1.720484e+08, 19485 iterations, 2.78 seconds (2.83 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7205e+08    0  144 2.5714e+07 1.7205e+08   569%     -    5s
# H    0     0                    1.684212e+08 1.7205e+08  2.15%     -    5s
# H    0     0                    1.716301e+08 1.7205e+08  0.24%     -    5s
# H    0     0                    1.717822e+08 1.7205e+08  0.15%     -    5s
# H    0     0                    1.718038e+08 1.7205e+08  0.14%     -    5s
# H    0     0                    1.718039e+08 1.7205e+08  0.14%     -    5s
#      0     0 1.7204e+08    0  138 1.7180e+08 1.7204e+08  0.14%     -    5s
#      0     0 1.7204e+08    0  112 1.7180e+08 1.7204e+08  0.14%     -    6s
#      0     0 1.7201e+08    0  113 1.7180e+08 1.7201e+08  0.12%     -    6s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Cover: 1
#   MIR: 2
#   StrongCG: 1
#
# Explored 1 nodes (22844 simplex iterations) in 6.93 seconds (5.89 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 1.71804e+08 1.71804e+08 1.71782e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.718039223319e+08, best bound 1.719534435348e+08, gap 0.0870%
# 7.31744122505188
# Set parameter MIPGap to value 0.001
# 0.46179723739624023
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 1.2197082042694092
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 62560 rows, 13250 columns and 138366 nonzeros
# Model fingerprint: 0x36501886
# Variable types: 0 continuous, 13250 integer (13250 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 8952 rows and 4264 columns
# Presolve time: 1.07s
# Presolved: 53608 rows, 8986 columns, 116322 nonzeros
# Variable types: 0 continuous, 8986 integer (8986 binary)
# Found heuristic solution: objective 4827266.9427
# Root relaxation presolved: 8983 rows, 62588 columns, 125296 nonzeros
#
#
# Root relaxation: objective 1.565607e+08, 20697 iterations, 1.34 seconds (1.44 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.5656e+08    0  107 4827266.94 1.5656e+08  3143%     -    2s
# H    0     0                    1.531300e+08 1.5656e+08  2.24%     -    2s
# H    0     0                    1.555750e+08 1.5656e+08  0.63%     -    3s
# H    0     0                    1.555851e+08 1.5656e+08  0.63%     -    3s
# H    0     0                    1.556313e+08 1.5656e+08  0.60%     -    3s
# H    0     0                    1.561923e+08 1.5656e+08  0.24%     -    4s
# H    0     0                    1.562491e+08 1.5656e+08  0.20%     -    4s
# H    0     0                    1.563426e+08 1.5654e+08  0.13%     -    4s
# H    0     0                    1.563974e+08 1.5654e+08  0.09%     -    4s
#
# Cutting planes:
#   MIR: 2
#   StrongCG: 2
#
# Explored 1 nodes (20697 simplex iterations) in 4.43 seconds (3.65 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 1.56397e+08 1.56343e+08 1.56249e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.563974298155e+08, best bound 1.565342636155e+08, gap 0.0875%
# 4.759785175323486
# Set parameter MIPGap to value 0.001
# 0.6043543815612793
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 1.0571725368499756
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 51545 rows, 11722 columns and 114808 nonzeros
# Model fingerprint: 0xd3f3c1de
# Variable types: 0 continuous, 11722 integer (11722 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 5181 rows and 3572 columns
# Presolve time: 0.47s
# Presolved: 46364 rows, 8150 columns, 100994 nonzeros
# Variable types: 0 continuous, 8150 integer (8150 binary)
# Found heuristic solution: objective 3397387.8574
# Root relaxation presolved: 8150 rows, 54514 columns, 109144 nonzeros
#
#
# Root relaxation: objective 1.358294e+08, 11446 iterations, 0.47 seconds (0.41 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3583e+08    0  250 3397387.86 1.3583e+08  3898%     -    1s
# H    0     0                    1.293091e+08 1.3583e+08  5.04%     -    1s
# H    0     0                    1.350300e+08 1.3583e+08  0.59%     -    1s
# H    0     0                    1.354519e+08 1.3583e+08  0.28%     -    2s
# H    0     0                    1.354534e+08 1.3582e+08  0.27%     -    2s
#      0     0 1.3579e+08    0  216 1.3545e+08 1.3579e+08  0.25%     -    2s
# H    0     0                    1.354713e+08 1.3579e+08  0.24%     -    3s
#      0     0 1.3578e+08    0  246 1.3547e+08 1.3578e+08  0.22%     -    3s
#      0     0 1.3569e+08    0   58 1.3547e+08 1.3569e+08  0.16%     -    4s
# H    0     0                    1.354786e+08 1.3569e+08  0.15%     -    4s
#      0     0 1.3569e+08    0  259 1.3548e+08 1.3569e+08  0.15%     -    4s
#      0     0 1.3568e+08    0  341 1.3548e+08 1.3568e+08  0.15%     -    4s
#      0     0 1.3565e+08    0  342 1.3548e+08 1.3565e+08  0.13%     -    5s
#      0     0 1.3564e+08    0  398 1.3548e+08 1.3564e+08  0.12%     -    5s
#      0     0 1.3563e+08    0  342 1.3548e+08 1.3563e+08  0.11%     -    5s
#      0     0 1.3563e+08    0  157 1.3548e+08 1.3563e+08  0.11%     -    6s
#      0     0 1.3563e+08    0  193 1.3548e+08 1.3563e+08  0.11%     -    7s
#      0     0 1.3563e+08    0  177 1.3548e+08 1.3563e+08  0.11%     -    7s
#      0     0 1.3563e+08    0  288 1.3548e+08 1.3563e+08  0.11%     -    7s
#      0     0 1.3563e+08    0  288 1.3548e+08 1.3563e+08  0.11%     -    7s
#      0     0 1.3561e+08    0  284 1.3548e+08 1.3561e+08  0.10%     -    7s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 3
#
# Explored 1 nodes (15591 simplex iterations) in 7.83 seconds (5.15 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 1.35479e+08 1.35471e+08 1.35453e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.354786025460e+08, best bound 1.356100836117e+08, gap 0.0970%
# 8.17717981338501
# Set parameter MIPGap to value 0.001
# 0.3530256748199463
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 0.9225363731384277
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 42321 rows, 10300 columns and 94938 nonzeros
# Model fingerprint: 0x6b6f4847
# Variable types: 0 continuous, 10300 integer (10300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4480 rows and 3257 columns
# Presolve time: 0.37s
# Presolved: 37841 rows, 7043 columns, 82841 nonzeros
# Variable types: 0 continuous, 7043 integer (7043 binary)
# Found heuristic solution: objective 3479074.3520
# Root relaxation presolved: 7042 rows, 44882 columns, 89880 nonzeros
#
#
# Root relaxation: objective 1.136886e+08, 13615 iterations, 0.48 seconds (0.49 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1369e+08    0   22 3479074.35 1.1369e+08  3168%     -    1s
# H    0     0                    1.130059e+08 1.1369e+08  0.60%     -    1s
# H    0     0                    1.132953e+08 1.1369e+08  0.35%     -    1s
# H    0     0                    1.136830e+08 1.1369e+08  0.00%     -    1s
#
# Explored 1 nodes (13615 simplex iterations) in 1.13 seconds (1.10 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1.13683e+08 1.13295e+08 1.13006e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.136829531218e+08, best bound 1.136885933845e+08, gap 0.0050%
# 1.405254602432251
# Set parameter MIPGap to value 0.001
# 0.33214640617370605
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 0.6951742172241211
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 32891 rows, 8702 columns and 74480 nonzeros
# Model fingerprint: 0x6ff3ffe1
# Variable types: 0 continuous, 8702 integer (8702 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3658 rows and 2849 columns
# Presolve time: 0.20s
# Presolved: 29233 rows, 5853 columns, 64434 nonzeros
# Variable types: 0 continuous, 5853 integer (5853 binary)
# Found heuristic solution: objective 3552972.7351
#
# Root relaxation: objective 9.341206e+07, 5025 iterations, 0.54 seconds (0.93 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9.3412e+07    0   79 3552972.74 9.3412e+07  2529%     -    0s
# H    0     0                    9.169469e+07 9.3412e+07  1.87%     -    0s
# H    0     0                    9.311372e+07 9.3412e+07  0.32%     -    0s
# H    0     0                    9.322609e+07 9.3412e+07  0.20%     -    0s
# H    0     0                    9.331060e+07 9.3412e+07  0.11%     -    0s
# H    0     0                    9.333425e+07 9.3412e+07  0.08%     -    1s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   StrongCG: 1
#
# Explored 1 nodes (5025 simplex iterations) in 1.11 seconds (1.38 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 9.33343e+07 9.33106e+07 9.32261e+07 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 9.333425443451e+07, best bound 9.341136148833e+07, gap 0.0826%
# 1.3284180164337158
# Set parameter MIPGap to value 0.001
# 0.2533235549926758
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 0.5425493717193604
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 24433 rows, 7140 columns and 56002 nonzeros
# Model fingerprint: 0x1a7e9df1
# Variable types: 0 continuous, 7140 integer (7140 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [3e+02, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3052 rows and 2472 columns
# Presolve time: 0.15s
# Presolved: 21381 rows, 4668 columns, 47545 nonzeros
# Variable types: 0 continuous, 4668 integer (4668 binary)
# Found heuristic solution: objective 4253756.7607
#
# Root relaxation: objective 7.192325e+07, 4665 iterations, 0.36 seconds (0.63 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.1923e+07    0  377 4253756.76 7.1923e+07  1591%     -    0s
# H    0     0                    6.670801e+07 7.1923e+07  7.82%     -    0s
# H    0     0                    7.091410e+07 7.1923e+07  1.42%     -    0s
# H    0     0                    7.102074e+07 7.1923e+07  1.27%     -    0s
# H    0     0                    7.128987e+07 7.1923e+07  0.89%     -    0s
# H    0     0                    7.153654e+07 7.1865e+07  0.46%     -    1s
#      0     0 7.1865e+07    0  386 7.1537e+07 7.1865e+07  0.46%     -    1s
# H    0     0                    7.153772e+07 7.1865e+07  0.46%     -    1s
# H    0     0                    7.161099e+07 7.1728e+07  0.16%     -    1s
#      0     0 7.1728e+07    0  387 7.1611e+07 7.1728e+07  0.16%     -    1s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 2
#
# Explored 1 nodes (4816 simplex iterations) in 2.16 seconds (1.78 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 7.1611e+07 7.15377e+07 7.15365e+07 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 7.161098759656e+07, best bound 7.166507128953e+07, gap 0.0755%
# 2.34663462638855
# Set parameter MIPGap to value 0.001
# 0.19049072265625
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 0.37998414039611816
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 15639 rows, 5344 columns and 36618 nonzeros
# Model fingerprint: 0xb41dcfe0
# Variable types: 0 continuous, 5344 integer (5344 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+02, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 2367 rows and 1977 columns
# Presolve time: 0.10s
# Presolved: 13272 rows, 3367 columns, 30021 nonzeros
# Variable types: 0 continuous, 3367 integer (3367 binary)
# Found heuristic solution: objective 4985821.9403
#
# Root relaxation: objective 5.091310e+07, 3869 iterations, 0.21 seconds (0.32 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.0913e+07    0   71 4985821.94 5.0913e+07   921%     -    0s
# H    0     0                    5.070111e+07 5.0913e+07  0.42%     -    0s
# H    0     0                    5.084792e+07 5.0913e+07  0.13%     -    0s
# H    0     0                    5.088251e+07 5.0913e+07  0.06%     -    0s
#
# Explored 1 nodes (3869 simplex iterations) in 0.44 seconds (0.49 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 5.08825e+07 5.08479e+07 5.07011e+07 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 5.088250688183e+07, best bound 5.091309685042e+07, gap 0.0601%
# 0.575463056564331
# Set parameter MIPGap to value 0.001
# 0.3011953830718994
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 0.22838973999023438
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 8656 rows, 3698 columns and 21006 nonzeros
# Model fingerprint: 0x9aa23c38
# Variable types: 0 continuous, 3698 integer (3698 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [4e+03, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 1664 rows and 1477 columns
# Presolve time: 0.09s
# Presolved: 6992 rows, 2221 columns, 16291 nonzeros
# Variable types: 0 continuous, 2221 integer (2221 binary)
# Found heuristic solution: objective 1732899.9933
#
# Root relaxation: objective 3.163992e+07, 2717 iterations, 0.09 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.1640e+07    0   96 1732899.99 3.1640e+07  1726%     -    0s
# H    0     0                    3.086767e+07 3.1640e+07  2.50%     -    0s
# H    0     0                    3.137748e+07 3.1640e+07  0.84%     -    0s
# H    0     0                    3.162644e+07 3.1640e+07  0.04%     -    0s
#
# Explored 1 nodes (2717 simplex iterations) in 0.24 seconds (0.20 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 3.16264e+07 3.13775e+07 3.08677e+07 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 3.162644298690e+07, best bound 3.163992254256e+07, gap 0.0426%
# 0.33461666107177734
# Set parameter MIPGap to value 0.001
# 0.06785082817077637
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 0, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, -1, 3), (-1, 0, 3), (-1, 1, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, -1, 3), (0, 0, 3), (0, 1, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, -1, 3), (1, 0, 3), (1, 1, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
# 0.10469913482666016
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3300 rows, 1910 columns and 8506 nonzeros
# Model fingerprint: 0x8b7382f1
# Variable types: 0 continuous, 1910 integer (1910 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [4e+03, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+07, 6e+07]
# Found heuristic solution: objective -0.0000000
# Presolve removed 963 rows and 872 columns
# Presolve time: 0.02s
# Presolved: 2337 rows, 1038 columns, 5772 nonzeros
# Variable types: 0 continuous, 1038 integer (1038 binary)
# Found heuristic solution: objective 941922.31473
#
# Root relaxation: objective 9.134538e+06, 1097 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9134537.52    0   39 941922.315 9134537.52   870%     -    0s
# H    0     0                    9104806.6386 9134537.52  0.33%     -    0s
# H    0     0                    9110432.0625 9134537.52  0.26%     -    0s
# H    0     0                    9122200.9617 9134537.52  0.14%     -    0s
#      0     0 9130936.96    0   44 9122200.96 9130936.96  0.10%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#
# Explored 1 nodes (1100 simplex iterations) in 0.10 seconds (0.04 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 9.1222e+06 9.11043e+06 9.10481e+06 ... -0
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 9.122200961682e+06, best bound 9.130936963569e+06, gap 0.0958%
# 0.15557003021240234
# 10 1018396950.3794813

# %%
# Out:
# 10
# 1018396950.3794813

# %%
import plotly.graph_objects as go

import numpy as np

def plot_blocks_3d_plotly(points):
    fig = go.Figure()

    x_coords = [p[0] for p in points]
    y_coords = [p[1] for p in points]
    z_coords = [p[2] for p in points]

    # Add points as scatter3d trace
    fig.add_trace(go.Scatter3d(x=x_coords, y=y_coords, z=z_coords,
                               mode='markers',
                               marker=dict(size=5, color='blue', opacity=0.8)))

    # Update layout
    fig.update_layout(scene=dict(
                        xaxis=dict(nticks=4, range=[min(x_coords)-1, max(x_coords)+1]),
                        yaxis=dict(nticks=4, range=[min(y_coords)-1, max(y_coords)+1]),
                        zaxis=dict(nticks=4, range=[min(z_coords)-1, max(z_coords)+1])),
                      width=700, height=700,
                      title="3D Block Representation of Points")
    
    fig.update_traces(marker=dict(symbol='square',size=5,line=dict(width=1,color='black')))


    fig.show()

# Example usage
points_3d = [(-1, 0, 1), (0, -1, 1), (0, 0, 1), (0, 1, 1), (1, 0, 1), (-2, 0, 2), (-1, -1, 2), (-1, 0, 2), (-1, 1, 2), (0, -2, 2), (0, -1, 2), (0, 1, 2), (0, 2, 2), (1, -1, 2), (1, 0, 2), (1, 1, 2), (2, 0, 2), (-3, 0, 3), (-2, -2, 3), (-2, -1, 3), (-2, 0, 3), (-2, 1, 3), (-2, 2, 3), (-1, -2, 3), (-1, 2, 3), (0, -3, 3), (0, -2, 3), (0, 2, 3), (0, 3, 3), (1, -2, 3), (1, 2, 3), (2, -2, 3), (2, -1, 3), (2, 0, 3), (2, 1, 3), (2, 2, 3), (3, 0, 3)]
plot_blocks_3d_plotly(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import plotly.graph_objects as go
#       3 import numpy as np
#       5 def plot_blocks_3d_plotly(points):
#
# ModuleNotFoundError: No module named 'plotly'
